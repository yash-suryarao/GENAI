# %% [markdown]
# a) Basic Prompting
#
# Gemini

# %%
# Basic Prompting using Gemini API
from google import genai
client = genai.Client(api_key="AIzaSyAxdttQ4nZeZXIX8ZwUpLXCqAG7_Qki6DE")
model = "gemini-2.0-flash"
user_input = "What is Gen AI?"
response = client.models.generate_content(model=model,contents=user_input,)
print(response.text)
# Out:
# Gen AI stands for **Generative Artificial Intelligence**. It refers to a category of AI models that can generate new and original content, ranging from text and images to audio, video, and even code. Unlike traditional AI, which primarily focuses on tasks like classification, prediction, or pattern recognition, Gen AI *creates* something new.
#
# Here's a breakdown of what's important about Gen AI:
#
# *   **Generative:** The core aspect is the ability to *generate* new data. This is distinct from simply analyzing or processing existing data.
# *   **Artificial Intelligence:** It leverages machine learning algorithms, particularly deep learning, to learn patterns and structures from vast datasets. It then uses this knowledge to produce content that resembles the data it was trained on.
# *   **Content Creation:** Gen AI can create a wide range of content, including:
#     *   **Text:** Writing articles, stories, scripts, poems, code, summaries, and even answering questions in a creative and informative way.
#     *   **Images:** Generating realistic or artistic images from text descriptions (text-to-image), modifying existing images, or creating entirely new visual concepts.
#     *   **Audio:** Composing music, creating sound effects, generating speech (text-to-speech), and synthesizing voices.
#     *   **Video:** Creating short video clips, animations, or manipulating existing video content.
#     *   **Code:** Generating code snippets or even entire programs based on specifications.
#     *   **3D models:** Creating 3D models from text prompts or images.
#
# **Key Concepts & Technologies:**
#
# *   **Large Language Models (LLMs):**  These are a crucial part of text-based Gen AI. They are trained on massive amounts of text data and can generate human-like text. Examples include GPT-3, GPT-4, Bard, LaMDA, and Llama.
# *   **Diffusion Models:** These are particularly successful in image and video generation.  They work by adding noise to an image until it's pure noise, and then learning to reverse the process, starting from noise and gradually refining it into a coherent image based on a prompt.  Examples include DALL-E 2, Stable Diffusion, and Midjourney.
# *   **Generative Adversarial Networks (GANs):**  GANs consist of two neural networks, a generator and a discriminator, that are trained against each other. The generator tries to create realistic content, while the discriminator tries to distinguish between real and generated content.  This adversarial process leads to increasingly realistic output.
#
# **Examples of Gen AI in Use:**
#
# *   **Content Creation:** Marketing teams using AI to generate ad copy, blog posts, and social media content.
# *   **Art and Design:** Artists using AI to create unique visual art or designers using it to explore design options.
# *   **Software Development:** Developers using AI to generate code snippets or complete functions.
# *   **Customer Service:**  Chatbots that provide personalized and helpful responses to customer inquiries.
# *   **Education:** AI tools that can create personalized learning materials or provide feedback on student work.
# *   **Entertainment:**  Creating realistic special effects for movies or generating new music.
#
# **Important Considerations:**
#
# *   **Bias:** Gen AI models are trained on data, and if that data contains biases, the models will likely reproduce those biases in their output.
# *   **Copyright and Ownership:** The ownership of content created by AI is a complex legal issue that is still being debated.
# *   **Misinformation:** The ability to generate realistic-looking content raises concerns about the potential for misuse in spreading misinformation or creating deepfakes.
# *   **Job displacement:** There are concerns about the potential for Gen AI to automate jobs currently done by humans, particularly in creative fields.
# *   **Hallucination:**  LLMs can sometimes generate incorrect or nonsensical information that sounds plausible but is factually wrong. This is often referred to as "hallucination."
#
# In summary, Gen AI represents a significant advancement in AI, with the power to create new content in a variety of formats. While it offers exciting possibilities, it also raises important ethical and societal considerations that need to be addressed.

# %%
# 2. Basic Prompting using OpenAI
from openai import OpenAI
client = OpenAI(api_key=openai_api_key)

response = client.responses.create(
    model="gpt-5",
    input="Write a short bedtime story about a unicorn."
)

print(response.output_text)

# %%
# Basic role-based prompting using OpenAI Open Router
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=openrouter_api_key,
)

completion = client.chat.completions.create(
  model="openai/gpt-oss-20b:free",
  messages=[
    {
      "role": "user",
      "content": "Tell me about india in short"
    }
  ]
)

# %%
# Basic Prompting using Huggingface model
from transformers import pipeline

genrator = pipeline('text-generation', model='gpt2')
prompt = "Tell me about India?"
output = genrator(prompt, max_length=50, num_return_sequences=1)
print("\nResponse: ",output[0]['generated_text'])

# %% [markdown]
# b) Instruction based prompting
#
# Gemini

# %%
# 1. Instruction based prompting, Using Gemini API.

import google.generativeai as genai
genai.configure(api_key="AIzaSyAxdttQ4nZeZXIX8ZwUpLXCqAG7_Qki6DE")
prompt = """
List the top 5 human activities contributing to climate change.
For each, give a one-line explanation of its impact.
Format the answer as a numbered list.
"""
model = genai.GenerativeModel("gemini-2.0-flash")
response = model.generate_content(prompt)
print(response.text)
# Out:
# Here are the top 5 human activities contributing to climate change:
#
# 1.  **Burning Fossil Fuels:** Burning coal, oil, and natural gas releases large amounts of carbon dioxide and other greenhouse gases into the atmosphere, trapping heat and warming the planet.
# 2.  **Deforestation:** Clearing forests reduces the number of trees that absorb carbon dioxide from the atmosphere, and burning the trees releases stored carbon.
# 3.  **Agriculture:** Livestock farming, fertilizer use, and rice cultivation release significant amounts of methane and nitrous oxide, potent greenhouse gases.
# 4.  **Industrial Processes:** Manufacturing processes, such as cement production and the creation of chemicals, release greenhouse gases directly into the atmosphere.
# 5.  **Transportation:** Cars, trucks, planes, and ships that rely on fossil fuels emit large quantities of carbon dioxide and other pollutants that contribute to global warming.

# %%
# Hugging Face
from transformers import pipeline

genrator = pipeline('text-generation', model='gpt2')

prompt = """
Summarize India briefly.
Focus on specific key aspects (geography, culture, history, economy).
Keep the response concise (3-4 sentences).
"""

output = genrator(prompt, max_length=50, num_return_sequences=1)

print("\nResponse: ",output[0]['generated_text'])

# %%
# Open AI using Open Router
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=openrouter_api_key,
)

completion = client.chat.completions.create(
  model="openai/gpt-oss-20b:free",
  messages=[
    {
      "role": "user",
      "content": """
        Summarize India briefly.
        Focus on specific key aspects (geography, culture, history, economy).
        Keep the response concise (3-4 sentences).
      """
    }
  ]
)
print(completion.choices[0].message.content)

# %%
# Role-based Prompting using OpenAI
from openai import OpenAI

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key="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",
)

completion = client.chat.completions.create(
  model="openai/gpt-oss-20b:free",
  messages=[
    {
      "role": "user",
      "content": "What is the meaning of life?"
    }
  ]
)
print(completion.choices[0].message.content)
# Out:
# The question “What is the meaning of life?” has occupied philosophers, theologians, scientists, and ordinary people for millennia. Because it touches on the deepest aspects of human existence—purpose, value, and the nature of reality—there is no single, universally accepted answer. Below is a concise overview of some of the most influential perspectives, each offering its own insights and challenges.
#
# | Perspective | Core Idea | Typical Proponents | Key Questions it Raises |
# |-------------|-----------|--------------------|------------------------|
# | **Religious (monotheistic, polytheistic, etc.)** | Life has a divine purpose; humans are created to fulfill a cosmic plan or moral code. | Christianity, Islam, Hinduism, Buddhism (through rituals, devotion, or enlightenment). | What evidence supports a divine plan? How do differing doctrines reconcile? |
# | **Philosophical Naturalism** | Life’s meaning is derived from natural processes; existence is explained by physics, biology, and evolution. | Darwinism, contemporary analytic philosophers like Daniel Dennett. | Can work, relationships, or the pursuit of knowledge constitute “meaning” without supernatural anchors? |
# | **Existentialism** | Each individual creates his or her own meaning in a universe that is inherently indifferent or absurd. | Sartre, Camus, Kierkegaard. | How can meaning be validated if it’s self‑constructed? What responsibility does one carry? |
# | **Humanism** | Meaning comes from human flourishing, compassion, and the betterment of society. | Secular humanism, many scientists and ethicists. | Can a purely secular ethic provide the depth and stability that religious traditions claim? |
# | **Nihilism** | Life has no inherent meaning; all values are arbitrary. | Some strands of post-structuralism; Friedrich Nietzsche (later work). | If meaning is fictional, how does one live coherently? |
# | **Eudaimonism (Aristotelian ethics)** | True meaning arises from fulfilling human potential (virtue, excellence, flourishing). | Aristotle, contemporary virtue ethicists. | What constitutes “flourishing” in a modern, diverse world? |
# | **Social Constructivism** | Meaning is socially constructed through language, institutions, and shared narratives. | Wittgenstein, social scientists. | How do power dynamics shape what counts as “meaningful”? |
#
# ### Common Threads
#
# 1. **Purpose vs. Value**
#    - Many traditions distinguish *purpose* (“Why are we here?”) from *value* (“What makes something worthy?"). Even if life lacks a predetermined purpose, humans can still create value via relationships, creativity, or stewardship.
#
# 2. **The Role of Suffering and Freedom**
#    - Some argue that suffering sharpens meaning, while others view freedom as the key to purposeful living. In existentialism, the sense of freedom coupled with responsibility is both exhilarating and daunting.
#
# 3. **Community and Solitude**
#    - Religious and humanist accounts often emphasize community as a wellspring of meaning. Conversely, existentialism and some humanist strains elevate individual experience—solitude—as the site of authentic self‑creation.
#
# ### How to Approach the Question Personally
#
# 1. **Reflect on what resonates**
#    *Which of the above themes (purpose, autonomy, service, flourishing) aligns most deeply with your lived experience?*
#
# 2. **Consider multiple lenses**
#    *Often, the richest understanding comes from integrating insights rather than committing to one universal verdict.*
#
# 3. **Experiment with practice**
#    *Engage in activities that foster connection, creativity, reflection, or ethical action. Notice how these interventions impact your sense of purpose.*
#
# 4. **Stay open to evolution**
#    *Meaning is rarely static. Life’s circumstances (relationships, health, society) shape our priorities. Regular reassessment can keep your sense of meaning alive and dynamic.*
#
# ### Bottom Line
#
# - **No definitive, global answer has emerged.** The meaning of life is a deeply personal, yet profoundly communal, question.
# - **Meaning can be self‑created.** Even if the universe is indifferent, human agency provides the tools for constructing projects, relationships, and values that feel significant.
# - **Every worldview offers partial insights.** Faith, science, philosophy, and everyday experience all contribute pieces to the larger puzzle.
#
# Ultimately, the search itself—questioning, reflecting, experimenting—can become as meaningful as any single conclusion. The field remains open, inviting ongoing dialogue and personal exploration.

# %%
# Role-based prompting using OpenAI

from openai import OpenAI
import os
# Create a client using your API key
client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key="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",)
# Make a request to GPT model
response = client.chat.completions.create(
    model="gpt-4o-mini",   # free & cheaper model
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain linear regression in simple terms with 3 real-time example."}
    ]
)
print(response.choices[0].message.content)
# Out:
# Linear regression is a statistical method used to model the relationship between a dependent variable (the outcome you want to predict) and one or more independent variables (the predictors). In simple terms, it helps us understand how changes in the independent variables can affect the dependent variable by fitting a straight line (or a hyperplane in multiple dimensions) to the data.
#
# ### Example 1: House Prices
# Imagine you want to predict the price of a house based on its size (measured in square feet). In linear regression, you would collect data on various houses, including their sizes and sale prices. You can plot this data on a graph, where the x-axis represents the size of the house, and the y-axis represents the price. A linear regression model would help you find the best-fitting straight line through the data points. This line can then be used to estimate house prices for sizes that you haven't seen yet.
#
# ### Example 2: Study Time and Exam Scores
# Suppose you’re curious about how the number of hours students study affects their exam scores. You could collect data from students about how many hours they studied and their corresponding scores. Plotting this data on a graph, the x-axis would represent study hours, and the y-axis would represent exam scores. By applying linear regression, you would find a line that best fits the points on the graph. This line can help predict a student's score based on their study time – for example, if a student studies for 5 hours, what score might they expect to achieve?
#
# ### Example 3: Advertising Spend and Sales Revenue
# Consider a business trying to understand the effect of its advertising budget on sales revenue. You gather data on how much the business spends on advertising each month and the revenue generated in those months. By plotting advertising spend on the x-axis and sales revenue on the y-axis and applying linear regression, you can find a line that indicates how sales revenue tends to increase or decrease with changes in advertising spending. This helps the business understand how much to invest in advertising to achieve desired sales levels.
#
# In all these examples, linear regression allows us to predict outcomes based on trends observed in the data and understand the strength of the relationships between variables.
